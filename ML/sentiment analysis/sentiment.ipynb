# %%
import pandas as pd
comments=pd.read_excel('evaluations_overall_comments.xlsx')

# %%
comments
# Out:
#          Target:                      Evaluator:       Rotation Dates:  \
# 0     Eliza Chen      Dr. Ong, Andrew Ming Liang    7/1/2022-7/31/2022
# 1     Eliza Chen         Dr. Chan, Webber Pak Wo    7/1/2022-7/31/2022
# 2     Eliza Chen              Dr. Lim, Chee Hooi    7/1/2022-7/31/2022
# 3     Eliza Chen         Dr. Chang, Jason Pik Eu    8/1/2022-8/31/2022
# 4     Eliza Chen              Dr. Tan, Chee Kiat    8/1/2022-8/31/2022
# ..           ...                             ...                   ...
# 163  Rachel Yeap     Dr. Tan, Malcolm Teck Kiang    7/1/2022-7/31/2022
# 164  Rachel Yeap  Dr. Khor, Christopher Jen Lock    8/1/2022-8/31/2022
# 165  Rachel Yeap               Dr. Liou, Wei Lun    8/1/2022-8/31/2022
# 166  Rachel Yeap             Dr. Loo, Khang Ning    9/1/2022-10/2/2022
# 167  Rachel Yeap        Dr. Kwek, Andrew Boon Eu  10/3/2022-10/31/2022
#
#                          Service:  \
# 0                             - -
# 1       SHS-GASTRO:BASIC ENDO-SGH
# 2       SHS-GASTRO:BASIC ENDO-SGH
# 3       SHS-GASTRO:BASIC ENDO-SGH
# 4       SHS-GASTRO:BASIC ENDO-SGH
# ..                            ...
# 163  SHS-GASTRO:GEN GASTROHEP-SGH
# 164  SHS-GASTRO:GEN GASTROHEP-SGH
# 165  SHS-GASTRO:GEN GASTROHEP-SGH
# 166            SHS-IM:GEN MED-SGH
# 167       SHS-GASTRO:ADV ENDO-CGH
#
#                                                Answer:
# 0    Eliza Chen is starting out and therefore as ex...
# 1    As a new senior resident to gastroenterology, ...
# 2                                           No concern
# 3    Overall I would rate Eliza Chen highly as a SR...
# 4    Eliza Chen has a quiet disposition and gives g...
# ..                                                 ...
# 163  did a week of bleeder call, good mgmt plans an...
# 164  very competent, extremely professional, and a ...
# 165  No issue. Making good progress compared to fir...
# 166  Rachel is clinically competent and I can trust...
# 167  Able to summarise key issues and suggest a rea...
#
# [168 rows x 5 columns]

# %%
#install vaderSentimentlibrary
# !pip install vaderSentiment

#import the library
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

#calculate the negative, positive, neutral and compound scores, plus verbal evaluation
def sentiment_vader(sentence):

    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()

    sentiment_dict = sid_obj.polarity_scores(sentence)
    negative = sentiment_dict['neg']
    neutral = sentiment_dict['neu']
    positive = sentiment_dict['pos']
    compound = sentiment_dict['compound']

    if sentiment_dict['compound'] >= 0.05 :
        overall_sentiment = "Positive"

    elif sentiment_dict['compound'] <= - 0.05 :
        overall_sentiment = "Negative"

    else :
        overall_sentiment = "Neutral"
  
    # return negative, neutral, positive, compound, overall_sentiment
    return compound


comments['Vader1 Score']=comments.apply(lambda x: sentiment_vader(x['Answer:']),axis=1)
comments['Vader1 Score']
# Out:
# 0      0.8954
# 1      0.2732
# 2     -0.2960
# 3      0.8807
# 4      0.6290
#         ...
# 163    0.3818
# 164    0.7425
# 165    0.5423
# 166    0.7184
# 167    0.5719
# Name: Vader1 Score, Length: 168, dtype: float64

# %%
comments[['Vader1 Score','Answer:']].loc[comments['Target:'] == 'Andre Tan']
# Out:
#      Vader1 Score                                            Answer:
# 115        0.6801  Andre could improve by showing more motivation...
# 116        0.5267  Whilst Andre puts in effort to review patients...
# 117        0.6353  He needs to be more proactive in learning . He...
# 118        0.6124               Works well with team. Reliable, safe
# 119        0.4588  Andre showed some improvement in his IBD knowl...
# 120        0.1027  I think overall whilst Andre is not a malignan...
# 121        0.4588  He is making some improvement with feedback in...
# 122        0.7506  We had discussed previously about Andre's 5 pe...
# 123        0.8442  Hope he will continue to improve in his clinic...
# 124        0.0000  Andre would need to show more dedication to le...
# 125        0.4927                                          very good
# 126        0.4404                                     good co worker

# %%
comments[['Answer:']].loc[comments['Vader1 Score'] == 0.0000]
# Out:
#                                                Answer:
# 10   Overall, her performance is within the level o...
# 20   able to act independently in most of the clini...
# 21   Gabrielle is a hardworking SR who puts in extr...
# 28                   hardworking, reliable, teamplayer
# 50                 Able to work almost independently.n
# 65   Dr. Li is a hardworking SR that has the requir...
# 81   Sam has all the qualities and skills expected ...
# 83                Sam is very steady and a reliable SR
# 84                             Progressing as expected
# 101  Meets expectation. Continue to work on medical...
# 113                            As per earlier comments
# 124  Andre would need to show more dedication to le...
# 127  Functions at 3rd year SR level. Able to indepe...
# 133       Fully functioning and independent specialist
# 139  I have not written much in this assessment. It...
# 160                            will need more guidance
# 161             His training is on track for his stage

# %%
# install textblob
# !pip install textblob

# import it
from textblob import TextBlob

#call the classifier
def sentiment_texblob(row):
  
    classifier = TextBlob(row)
    polarity = classifier.sentiment.polarity
    subjectivity = classifier.sentiment.subjectivity
    
    return polarity

comments['Textblob Score']=comments.apply(lambda x: sentiment_texblob(x['Answer:']),axis=1)
comments['Textblob Score']
# Out:
# 0      0.171429
# 1      0.136364
# 2      0.000000
# 3      0.263750
# 4      0.330000
#          ...
# 163    0.440625
# 164    0.375000
# 165    0.475000
# 166    0.000000
# 167    0.233333
# Name: Textblob Score, Length: 168, dtype: float64

# %%
comments[['Answer:']].loc[comments['Textblob Score'] == 0.000000]
# Out:
#                                                Answer:
# 2                                           No concern
# 5                            Please see comments above
# 6    Conscientious, thorough, works in a team, keen...
# 10   Overall, her performance is within the level o...
# 12   Meets expectation. Has improved in terms of cl...
# 14                She has improved a lot. Trustworthy.
# 18                                          No concern
# 21   Gabrielle is a hardworking SR who puts in extr...
# 24   Meets expectation. Dependable and guides junio...
# 25                                    Progressing well
# 28                   hardworking, reliable, teamplayer
# 32   Hyun Bin is hardworking and keeps up with his ...
# 33                     Functional and Efficient Worker
# 35   Pleasure working with Hyun Bin. Communicates h...
# 44   Amanda is settling into the programme well. Di...
# 49   Justin is a motivated learner. His patient int...
# 65   Dr. Li is a hardworking SR that has the requir...
# 70   Coping well and learning the system of trainin...
# 73   He has performed well with endoscopy skills fo...
# 86   To pick up on some research projects to expand...
# 89          Knowledge aspect needs further improvement
# 101  Meets expectation. Continue to work on medical...
# 104                   Improving well well. Settled now
# 113                            As per earlier comments
# 119  Andre showed some improvement in his IBD knowl...
# 121  He is making some improvement with feedback in...
# 123  Hope he will continue to improve in his clinic...
# 133       Fully functioning and independent specialist
# 144  Shows leadership qualities and teaching abilities
# 158  Meets expectations. Continue to improve on med...
# 161             His training is on track for his stage
# 162  Rachel has demonstrated maturity in leading he...
# 166  Rachel is clinically competent and I can trust...

# %%
# !pip install happytransformer
from happytransformer import HappyTextClassification
happy_tc=HappyTextClassification(model_type='DISTILBERT',model_name='distilbert-base-uncased-finetuned-sst-2-english',num_labels=2)
comments['Transformer Score']=comments.apply(lambda x: happy_tc.classify_text(x['Answer:']),axis=1)
# Out:
# Requirement already satisfied: happytransformer in c:\users\wongqihuiyve\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: sentencepiece in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from happytransformer) (0.1.97)
# Requirement already satisfied: protobuf in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from happytransformer) (4.22.1)
# Requirement already satisfied: datasets>=1.6.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from happytransformer) (2.10.1)
# Requirement already satisfied: transformers>=4.4.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from happytransformer) (4.26.1)
# Requirement already satisfied: torch>=1.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from happytransformer) (1.13.1)
# Requirement already satisfied: tqdm>=4.43 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from happytransformer) (4.64.1)
# Requirement already satisfied: pandas in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (2.28.1)
# Requirement already satisfied: packaging in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (1.21.5)
# Requirement already satisfied: xxhash in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (3.2.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (6.0)
# Requirement already satisfied: responses<0.19 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (0.18.0)
# Requirement already satisfied: aiohttp in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (3.8.4)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (2022.7.1)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (11.0.0)
# Requirement already satisfied: multiprocess in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (0.70.14)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (0.3.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from datasets>=1.6.0->happytransformer) (0.13.2)
# Requirement already satisfied: typing-extensions in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from torch>=1.0->happytransformer) (4.3.0)
# Requirement already satisfied: colorama in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from tqdm>=4.43->happytransformer) (0.4.5)
# Requirement already satisfied: filelock in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from transformers>=4.4.0->happytransformer) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from transformers>=4.4.0->happytransformer) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from transformers>=4.4.0->happytransformer) (0.13.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from packaging->datasets>=1.6.0->happytransformer) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (1.26.11)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.8.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from pandas->datasets>=1.6.0->happytransformer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from pandas->datasets>=1.6.0->happytransformer) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\wongqihuiyve\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets>=1.6.0->happytransformer) (1.16.0)
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# c:\Users\WongQiHuiYve\Anaconda3\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\WongQiHuiYve\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# 03/22/2023 06:53:36 - INFO - happytransformer.happy_transformer -   Using model: cpu

# %%
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

n_gram_range = (1, 1)
stop_words = "english"

sentences=comments['Answer:'].values.tolist()
# Extract candidate words/phrases
count = CountVectorizer(ngram_range=n_gram_range, stop_words=stop_words).fit(sentences)
candidates = count.get_feature_names()

model = SentenceTransformer('distilbert-base-nli-mean-tokens')
# doc_embedding = model.encode([doc])
candidate_embeddings = model.encode(candidates)
# doc_embedding
comments['Doc_Embed']=comments.apply(lambda x: model.encode([x['Answer:']]),axis=1)
comments['Distance']=comments.apply(lambda x:cosine_similarity(x['Doc_Embed'],candidate_embeddings),axis=1)
top_n = 5

comments['Keywords']=comments['Distance'].apply(lambda x: [candidates[index] for index in x.argsort()[0][-top_n:]])

comments['Keywords']
# Out:
# c:\Users\WongQiHuiYve\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Batches:   0%|          | 0/28 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0      [outpatient, professionalism, holistic, teacha...
# 1      [pharmacists, medicine, inpatients, inpatient,...
# 2         [quiet, independently, minimal, passive, lack]
# 3       [medical, doctors, healthcare, nurses, medicine]
# 4        [caring, calm, diligent, polite, introspective]
#                              ...
# 163    [outpatient, medicine, colonoscopes, 2022, col...
# 164    [professionalism, treasured, reliable, efficie...
# 165      [maturity, completed, matures, mature, matured]
# 166    [doctors, medicine, inpatient, inpatients, nur...
# 167    [inpatients, medical, inpatient, healthcare, m...
# Name: Keywords, Length: 168, dtype: object

# %%
comments['Keywords']
# Out:
# 0      [outpatient, professionalism, holistic, teacha...
# 1      [pharmacists, medicine, inpatients, inpatient,...
# 2         [quiet, independently, minimal, passive, lack]
# 3       [medical, doctors, healthcare, nurses, medicine]
# 4        [caring, calm, diligent, polite, introspective]
#                              ...
# 163    [outpatient, medicine, colonoscopes, 2022, col...
# 164    [professionalism, treasured, reliable, efficie...
# 165      [maturity, completed, matures, mature, matured]
# 166    [doctors, medicine, inpatient, inpatients, nur...
# 167    [inpatients, medical, inpatient, healthcare, m...
# Name: Keywords, Length: 168, dtype: object

# %%
comments[['Keywords']].loc[comments['Vader1 Score'] <= 0.000000]
# Out:
#                                               Keywords
# 2       [quiet, independently, minimal, passive, lack]
# 10   [practice, competencies, requisite, discipline...
# 16   [matured, healthcare, inpatients, clinics, pro...
# 18      [quiet, independently, minimal, passive, lack]
# 19     [lacking, outpatient, short, limited, weakness]
# 20   [diligently, professionalism, clinical, mature...
# 21   [competing, competency, competencies, training...
# 28   [professionalism, proactive, reliable, hardwor...
# 50   [settled, independent, independently, efficien...
# 63    [overthinks, doubts, limited, receptive, unsure]
# 65   [dedication, requisite, professionalism, profe...
# 81     [confident, fully, greatest, obvious, complete]
# 83     [clear, safe, confident, trustworthy, reliable]
# 84   [progressing, usual, anticipated, expected, co...
# 101  [medical, healthcare, physician, doctors, medi...
# 113  [initial, replies, earlier, previously, previous]
# 124   [needed, learner, learning, training, educating]
# 127            [sr3, majority, 3rd, juniors, beginner]
# 133  [competent, complete, clear, confident, profes...
# 139  [usual, self, previously, previous, independen...
# 160          [wanting, necessary, needs, need, needed]
# 161  [stage, performer, fitness, performing, training]

# %%
comments[['Keywords']].loc[comments['Textblob Score'] <= 0.000000]
# Out:
#                                               Keywords
# 2       [quiet, independently, minimal, passive, lack]
# 5    [posting, presentation, discusses, presentatio...
# 6    [professionalism, trustworthy, training, teach...
# 10   [practice, competencies, requisite, discipline...
# 11   [competing, training, competencies, hardworkin...
# 12   [teachable, treatments, diagnostic, improvemen...
# 14   [improving, improves, efficient, receptive, im...
# 18      [quiet, independently, minimal, passive, lack]
# 19     [lacking, outpatient, short, limited, weakness]
# 21   [competing, competency, competencies, training...
# 24   [matured, adaptable, receptive, holistic, teac...
# 25   [confident, efficiently, satisfactory, confide...
# 28   [professionalism, proactive, reliable, hardwor...
# 32   [introspective, trustworthy, scientific, profe...
# 33   [trustworthy, professionalism, competent, reli...
# 35   [proactive, adaptable, happy, professionalism,...
# 44   [colleague, professionalism, teachable, collea...
# 49   [hardworking, teachable, reliable, professiona...
# 65   [dedication, requisite, professionalism, profe...
# 70   [educating, teaching, learning, teachable, tra...
# 73   [fitness, professionalism, teachable, training...
# 77   [doctors, inpatients, medicine, healthcare, in...
# 81     [confident, fully, greatest, obvious, complete]
# 84   [progressing, usual, anticipated, expected, co...
# 86   [training, teaching, inpatients, clinics, rese...
# 87   [requisite, teachable, training, educating, ha...
# 89   [improvement, necessary, needed, educating, im...
# 101  [medical, healthcare, physician, doctors, medi...
# 103  [matured, completed, requisite, beginner, hard...
# 104  [efficiently, confident, easily, safely, impro...
# 113  [initial, replies, earlier, previously, previous]
# 119  [effectiveness, improved, adaptable, improving...
# 121         [improving, month, daily, matured, months]
# 123  [trustworthy, teachable, improvement, improvin...
# 133  [competent, complete, clear, confident, profes...
# 135  [holistic, professionalism, introspective, har...
# 144  [teaches, educator, educating, teaching, teach...
# 158  [physician, doctors, medical, healthcare, medi...
# 161  [stage, performer, fitness, performing, training]
# 162  [teachable, trustworthy, ethic, professionalis...
# 166  [doctors, medicine, inpatient, inpatients, nur...

# %%
# WORDCLOUD
from itertools import chain
out = (comments.groupby('Target:', as_index=False)['Keywords']
         .agg(lambda x: list(chain.from_iterable(x)))
       )

# %%
out
# Out:
#              Target:                                           Keywords
# 0         Amanda Koh  [new, juniors, competing, outpatient, beginner...
# 1          Andre Tan  [improving, teaching, educating, colleagues, t...
# 2    Christopher Tan  [sr3, majority, 3rd, juniors, beginner, inpati...
# 3         Eliza Chen  [outpatient, professionalism, holistic, teacha...
# 4      Francisco Tan  [physician, healthcare, doctors, professionali...
# 5       Gabrielle Ho  [practice, competencies, requisite, discipline...
# 6         James Wang  [physician, medicine, doctors, inpatients, inp...
# 7      Jiang Xiao Ye  [respected, reliable, caring, trustworthy, pol...
# 8      Justin Bieber  [hardworking, teachable, reliable, professiona...
# 9      Kang Hyun Bin  [reliable, proactive, trustworthy, efficient, ...
# 10        Li Xiuhuan  [holistic, nurses, teaching, medicine, hardwor...
# 11      Pei Wei Ping  [training, teaching, inpatients, clinics, rese...
# 12     Qiu Tian Ning  [training, competency, teachable, competencies...
# 13       Rachel Yeap  [teachable, trustworthy, ethic, professionalis...
# 14  Rahul Rajaratnam  [reliable, diagnostic, professionalism, medici...
# 15           Sam Lim  [educating, teaching, learning, teachable, tra...
# 16       Tang Ye Bin  [holistic, professionalism, introspective, har...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate a word cloud for each row with title
for index, row in out.iterrows():
    text = ' '.join(row['Keywords'])
    wordcloud = WordCloud(background_color='white').generate(text)
    plt.figure()
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(row['Target:'])
    plt.show()

# %%
# BAR CHART BASED ON EVALUATOR

out2 =comments.groupby('Evaluator:')['Vader1 Score'].mean()

# %%
counts = comments['Evaluator:'].value_counts()

# %%
out2 = out2.to_frame().reset_index()
out2
# Out:
#                          Evaluator:  Vader1 Score
# 0      Dr. Abdul Halim, Nurul Aidah      0.624900
# 1              Dr. Ang, Tiing Leong      0.394500
# 2        Dr. Asokkumar, Ravishankar      0.495386
# 3    Dr. Balasubramanian, Diraviyam      0.844200
# 4           Dr. Chan, Webber Pak Wo      0.453267
# 5           Dr. Chang, Jason Pik Eu      0.781550
# 6              Dr. Cheah, Kee Leong      0.454850
# 7       Dr. Cheah, Mark Chang Chuen      0.650371
# 8             Dr. De Roza, Marianne      0.416767
# 9         Dr. Gan, Sheryl Shien Wen      0.948500
# 10               Dr. Goh, Kiat Sern      0.648600
# 11   Dr. Khor, Christopher Jen Lock      0.658550
# 12  Dr. Krishnamoorthy, Thinesh Lee      0.774500
# 13                 Dr. Kumar, Rahul      0.679367
# 14              Dr. Kumar, Rajneesh      0.696233
# 15       Dr. Kwan Kah Wai, Clarence      0.471850
# 16         Dr. Kwek, Andrew Boon Eu      0.505038
# 17     Dr. Lalmalani, Roshan Mahesh      0.700300
# 18            Dr. Li, James Weiquan      0.672087
# 19                  Dr. Li, Weishan      0.000000
# 20               Dr. Lim, Chee Hooi     -0.204575
# 21                 Dr. Lim, Kim Wei      0.106067
# 22               Dr. Lim, Miao Shan      0.399967
# 23      Dr. Lim, Thomson Chong Teik      0.139260
# 24         Dr. Lin Weicong, Kenneth      0.417850
# 25                  Dr. Lin, Cui Li      0.416600
# 26                Dr. Liou, Wei Lun      0.606483
# 27              Dr. Loo, Khang Ning      0.718400
# 28     Dr. Lum Huey Ming, Johnathan      0.879633
# 29         Dr. Nadarajan, Krithikaa      0.891000
# 30      Dr. Ng, Lawrence Cheng Kiat      0.765000
# 31       Dr. Ong, Andrew Ming Liang      0.768775
# 32              Dr. Ong, Chiew Sern      0.690800
# 33        Dr. Ong, Jeannie Peng Lan      0.645443
# 34              Dr. Ong, Wai Choung      0.442633
# 35                Dr. Ooi, Chun How      0.361200
# 36                     Dr. Qin, Yan      0.931300
# 37            Dr. Salazar, Ennaliza      0.472525
# 38            Dr. Sumit Kumar, Sonu      0.740200
# 39               Dr. Tan, Chee Kiat      0.758725
# 40               Dr. Tan, Chin Kimg      0.374220
# 41              Dr. Tan, Hiang Keat      0.518250
# 42      Dr. Tan, Malcolm Teck Kiang      0.695667
# 43        Dr. Tan, Terence Jin Yang      0.764825
# 44                 Dr. Tay, Shu Wen      0.304050
# 45           Dr. Teh, Kevin Kim Jun      0.681740
# 46                Dr. Tey, Tze Tong      0.795450
# 47         Dr. Tng, Alvin Ren Kwang      0.440400

# %%
counts= counts.to_frame().reset_index()

counts.columns = ['Evaluator:', 'Vader1 Score']
counts
# Out:
#                          Evaluator:  Vader1 Score
# 0             Dr. Salazar, Ennaliza             8
# 1             Dr. Li, James Weiquan             8
# 2          Dr. Kwek, Andrew Boon Eu             8
# 3       Dr. Cheah, Mark Chang Chuen             7
# 4        Dr. Asokkumar, Ravishankar             7
# 5         Dr. Ong, Jeannie Peng Lan             7
# 6           Dr. Chan, Webber Pak Wo             6
# 7                 Dr. Liou, Wei Lun             6
# 8                  Dr. Kumar, Rahul             6
# 9    Dr. Khor, Christopher Jen Lock             6
# 10      Dr. Tan, Malcolm Teck Kiang             6
# 11               Dr. Tan, Chin Kimg             5
# 12           Dr. Teh, Kevin Kim Jun             5
# 13      Dr. Lim, Thomson Chong Teik             5
# 14  Dr. Krishnamoorthy, Thinesh Lee             5
# 15              Dr. Tan, Hiang Keat             4
# 16        Dr. Tan, Terence Jin Yang             4
# 17         Dr. Lin Weicong, Kenneth             4
# 18       Dr. Ong, Andrew Ming Liang             4
# 19               Dr. Tan, Chee Kiat             4
# 20               Dr. Lim, Chee Hooi             4
# 21          Dr. Chang, Jason Pik Eu             4
# 22             Dr. Ang, Tiing Leong             3
# 23            Dr. De Roza, Marianne             3
# 24     Dr. Lum Huey Ming, Johnathan             3
# 25               Dr. Lim, Miao Shan             3
# 26                 Dr. Lim, Kim Wei             3
# 27              Dr. Ong, Wai Choung             3
# 28              Dr. Kumar, Rajneesh             3
# 29                Dr. Tey, Tze Tong             2
# 30       Dr. Kwan Kah Wai, Clarence             2
# 31             Dr. Cheah, Kee Leong             2
# 32                  Dr. Lin, Cui Li             2
# 33                 Dr. Tay, Shu Wen             2
# 34        Dr. Gan, Sheryl Shien Wen             1
# 35         Dr. Tng, Alvin Ren Kwang             1
# 36     Dr. Abdul Halim, Nurul Aidah             1
# 37                     Dr. Qin, Yan             1
# 38               Dr. Goh, Kiat Sern             1
# 39         Dr. Nadarajan, Krithikaa             1
# 40              Dr. Ong, Chiew Sern             1
# 41      Dr. Ng, Lawrence Cheng Kiat             1
# 42   Dr. Balasubramanian, Diraviyam             1
# 43            Dr. Sumit Kumar, Sonu             1
# 44                Dr. Ooi, Chun How             1
# 45                  Dr. Li, Weishan             1
# 46     Dr. Lalmalani, Roshan Mahesh             1
# 47              Dr. Loo, Khang Ning             1

# %%
test2 = pd.merge(out2,counts, on = ['Evaluator:'], how='left')
test3=test2[test2['Vader1 Score_y']>4]
test3
# Out:
#                          Evaluator:  Vader1 Score_x  Vader1 Score_y
# 2        Dr. Asokkumar, Ravishankar        0.495386               7
# 4           Dr. Chan, Webber Pak Wo        0.453267               6
# 7       Dr. Cheah, Mark Chang Chuen        0.650371               7
# 11   Dr. Khor, Christopher Jen Lock        0.658550               6
# 12  Dr. Krishnamoorthy, Thinesh Lee        0.774500               5
# 13                 Dr. Kumar, Rahul        0.679367               6
# 16         Dr. Kwek, Andrew Boon Eu        0.505038               8
# 18            Dr. Li, James Weiquan        0.672087               8
# 23      Dr. Lim, Thomson Chong Teik        0.139260               5
# 26                Dr. Liou, Wei Lun        0.606483               6
# 33        Dr. Ong, Jeannie Peng Lan        0.645443               7
# 37            Dr. Salazar, Ennaliza        0.472525               8
# 40               Dr. Tan, Chin Kimg        0.374220               5
# 42      Dr. Tan, Malcolm Teck Kiang        0.695667               6
# 45           Dr. Teh, Kevin Kim Jun        0.681740               5

# %%
test3.plot(x='Evaluator:', y='Vader1 Score_x', kind='bar')

# Set the title and axis labels
plt.title('Example Bar Chart')
plt.xlabel('Categories')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
comments[['Answer:','Vader1 Score']].loc[comments['Evaluator:']=='Dr. Lim, Thomson Chong Teik']
#fucking need finetuning bro
# Out:
#                                               Answer:  Vader1 Score
# 21  Gabrielle is a hardworking SR who puts in extr...        0.0000
# 42  Resident is SR1 and is quickly learning to man...        0.0258
# 54  Justin is a hardworking Gastro SR that is also...        0.6705
# 65  Dr. Li is a hardworking SR that has the requir...        0.0000
# 81  Sam has all the qualities and skills expected ...        0.0000

# %%
# BAR CHART BASED ON SERVICE
out3 =comments.groupby('Service:')['Vader1 Score'].mean()
out3 = out3.to_frame().reset_index()
out3
# Out:
#                               Service:  Vader1 Score
# 0                                  - -      0.722967
# 1              SHS-GASTRO:ADV ENDO-CGH      0.570992
# 2            SHS-GASTRO:BASIC ENDO-CGH      0.267750
# 3            SHS-GASTRO:BASIC ENDO-SGH      0.387554
# 4   SHS-GASTRO:GEN GASTROHEP(ELEC)-CGH      0.641262
# 5   SHS-GASTRO:GEN GASTROHEP(ELEC)-SGH      0.474425
# 6   SHS-GASTRO:GEN GASTROHEP(ELEC)-SKH      0.633067
# 7         SHS-GASTRO:GEN GASTROHEP-CGH      0.629730
# 8         SHS-GASTRO:GEN GASTROHEP-SGH      0.497309
# 9           SHS-GASTRO:IBD & NUTRI-SGH      0.613626
# 10                  SHS-GASTRO:LTX-SGH      0.693921
# 11                    SHS-GRM:GERI-CGH      0.618000
# 12                    SHS-GRM:GERI-SKH      0.700300
# 13                  SHS-IM:GEN MED-CGH      0.772000
# 14                  SHS-IM:GEN MED-SGH      0.621669
# 15                  SHS-IM:GEN MED-SKH      0.607420

# %%
out3.plot(x='Service:', y='Vader1 Score', kind='bar')

# Set the title and axis labels
plt.title('Example Bar Chart')
plt.xlabel('Categories')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
comments[['Answer:']].loc[comments['Service:']=='SHS-GASTRO:BASIC ENDO-CGH'].loc[102].values.tolist()
#bro need finetuning
# Out:
# ['Tian Ning is very competent as an SR1. She is able to identify gaps in her learning and to seek clarification when needed.']

# %%
# SCATTER PLOT BETWEEN COMMENT SCORE AND ANSWER SCORE
exam_score=pd.read_excel('evaluations_overall_score.xlsx')
exam_score['Answer']=exam_score['Answer:'].apply(lambda x:int(x[0]) )
exam_score= exam_score.drop('Answer:', axis=1)

# %%
comments
# Out:
#          Target:                      Evaluator:       Rotation Dates:  \
# 0     Eliza Chen      Dr. Ong, Andrew Ming Liang    7/1/2022-7/31/2022
# 1     Eliza Chen         Dr. Chan, Webber Pak Wo    7/1/2022-7/31/2022
# 2     Eliza Chen              Dr. Lim, Chee Hooi    7/1/2022-7/31/2022
# 3     Eliza Chen         Dr. Chang, Jason Pik Eu    8/1/2022-8/31/2022
# 4     Eliza Chen              Dr. Tan, Chee Kiat    8/1/2022-8/31/2022
# ..           ...                             ...                   ...
# 163  Rachel Yeap     Dr. Tan, Malcolm Teck Kiang    7/1/2022-7/31/2022
# 164  Rachel Yeap  Dr. Khor, Christopher Jen Lock    8/1/2022-8/31/2022
# 165  Rachel Yeap               Dr. Liou, Wei Lun    8/1/2022-8/31/2022
# 166  Rachel Yeap             Dr. Loo, Khang Ning    9/1/2022-10/2/2022
# 167  Rachel Yeap        Dr. Kwek, Andrew Boon Eu  10/3/2022-10/31/2022
#
#                          Service:  \
# 0                             - -
# 1       SHS-GASTRO:BASIC ENDO-SGH
# 2       SHS-GASTRO:BASIC ENDO-SGH
# 3       SHS-GASTRO:BASIC ENDO-SGH
# 4       SHS-GASTRO:BASIC ENDO-SGH
# ..                            ...
# 163  SHS-GASTRO:GEN GASTROHEP-SGH
# 164  SHS-GASTRO:GEN GASTROHEP-SGH
# 165  SHS-GASTRO:GEN GASTROHEP-SGH
# 166            SHS-IM:GEN MED-SGH
# 167       SHS-GASTRO:ADV ENDO-CGH
#
#                                                Answer:  Vader1 Score  \
# 0    Eliza Chen is starting out and therefore as ex...        0.8954
# 1    As a new senior resident to gastroenterology, ...        0.2732
# 2                                           No concern       -0.2960
# 3    Overall I would rate Eliza Chen highly as a SR...        0.8807
# 4    Eliza Chen has a quiet disposition and gives g...        0.6290
# ..                                                 ...           ...
# 163  did a week of bleeder call, good mgmt plans an...        0.3818
# 164  very competent, extremely professional, and a ...        0.7425
# 165  No issue. Making good progress compared to fir...        0.5423
# 166  Rachel is clinically competent and I can trust...        0.7184
# 167  Able to summarise key issues and suggest a rea...        0.5719
#
#      Textblob Score                                  Transformer Score  \
# 0          0.171429  TextClassificationResult(label='POSITIVE', sco...
# 1          0.136364  TextClassificationResult(label='POSITIVE', sco...
# 2          0.000000  TextClassificationResult(label='NEGATIVE', sco...
# 3          0.263750  TextClassificationResult(label='POSITIVE', sco...
# 4          0.330000  TextClassificationResult(label='POSITIVE', sco...
# ..              ...                                                ...
# 163        0.440625  TextClassificationResult(label='NEGATIVE', sco...
# 164        0.375000  TextClassificationResult(label='POSITIVE', sco...
# 165        0.475000  TextClassificationResult(label='POSITIVE', sco...
# 166        0.000000  TextClassificationResult(label='POSITIVE', sco...
# 167        0.233333  TextClassificationResult(label='POSITIVE', sco...
#
#                                              Doc_Embed  \
# 0    [[-0.6721534, -0.027664, 0.70268226, -0.476056...
# 1    [[-0.42423996, -0.6286227, 0.88219756, -0.6787...
# 2    [[-0.6876688, 0.02974713, 0.109754026, 0.12074...
# 3    [[-0.6283155, -0.20029192, 1.1669189, -0.10387...
# 4    [[-0.8619444, -0.18374743, 0.21259235, 0.16743...
# ..                                                 ...
# 163  [[0.1212126, -0.52477044, 1.1620986, -0.917062...
# 164  [[-0.2288021, -0.4193769, 0.4208119, 0.1031569...
# 165  [[-0.34792647, -1.0121427, 0.16201107, -1.0558...
# 166  [[-0.5686393, -0.43344223, 0.682797, 0.342227,...
# 167  [[-0.59468305, -0.25439933, 1.5317823, -0.1208...
#
#                                               Distance  \
# 0    [[-0.09625689, 0.11881207, 1.9541476e-05, 0.09...
# 1    [[-0.0859189, 0.17790526, -0.016277257, 0.0281...
# 2    [[0.6711223, 0.41983747, 0.5360163, 0.5921104,...
# 3    [[0.028535588, 0.28990865, 0.0832851, 0.186433...
# 4    [[-0.0062184343, 0.13000053, 0.01491292, 0.150...
# ..                                                 ...
# 163  [[-0.061233785, 0.28290597, 0.0270812, -0.0234...
# 164  [[0.2495091, 0.22908753, 0.33462763, 0.5758852...
# 165  [[0.42752415, 0.48969555, 0.44772327, 0.458115...
# 166  [[-0.14905263, 0.09871096, -0.12953652, 0.0126...
# 167  [[0.09124422, 0.28660053, 0.08596024, 0.294353...
#
#                                               Keywords
# 0    [outpatient, professionalism, holistic, teacha...
# 1    [pharmacists, medicine, inpatients, inpatient,...
# 2       [quiet, independently, minimal, passive, lack]
# 3     [medical, doctors, healthcare, nurses, medicine]
# 4      [caring, calm, diligent, polite, introspective]
# ..                                                 ...
# 163  [outpatient, medicine, colonoscopes, 2022, col...
# 164  [professionalism, treasured, reliable, efficie...
# 165    [maturity, completed, matures, mature, matured]
# 166  [doctors, medicine, inpatient, inpatients, nur...
# 167  [inpatients, medical, inpatient, healthcare, m...
#
# [168 rows x 11 columns]

# %%
score_comments=pd.merge(comments,exam_score, on = ['Target:','Evaluator:','Rotation Dates:','Service:'], how='left')

# %%
import seaborn as sns
sns.kdeplot(score_comments['Answer'])
# Out:
# <AxesSubplot:xlabel='Answer', ylabel='Density'>

# %%
sns.kdeplot(score_comments['Vader1 Score'])
# Out:
# <AxesSubplot:xlabel='Vader1 Score', ylabel='Density'>

# %%
score_comments.hist(figsize=[10,10])
plt.show()

# %%
score_comments
# Out:
#          Target:                      Evaluator:       Rotation Dates:  \
# 0     Eliza Chen      Dr. Ong, Andrew Ming Liang    7/1/2022-7/31/2022
# 1     Eliza Chen         Dr. Chan, Webber Pak Wo    7/1/2022-7/31/2022
# 2     Eliza Chen              Dr. Lim, Chee Hooi    7/1/2022-7/31/2022
# 3     Eliza Chen         Dr. Chang, Jason Pik Eu    8/1/2022-8/31/2022
# 4     Eliza Chen              Dr. Tan, Chee Kiat    8/1/2022-8/31/2022
# ..           ...                             ...                   ...
# 163  Rachel Yeap     Dr. Tan, Malcolm Teck Kiang    7/1/2022-7/31/2022
# 164  Rachel Yeap  Dr. Khor, Christopher Jen Lock    8/1/2022-8/31/2022
# 165  Rachel Yeap               Dr. Liou, Wei Lun    8/1/2022-8/31/2022
# 166  Rachel Yeap             Dr. Loo, Khang Ning    9/1/2022-10/2/2022
# 167  Rachel Yeap        Dr. Kwek, Andrew Boon Eu  10/3/2022-10/31/2022
#
#                          Service:  \
# 0                             - -
# 1       SHS-GASTRO:BASIC ENDO-SGH
# 2       SHS-GASTRO:BASIC ENDO-SGH
# 3       SHS-GASTRO:BASIC ENDO-SGH
# 4       SHS-GASTRO:BASIC ENDO-SGH
# ..                            ...
# 163  SHS-GASTRO:GEN GASTROHEP-SGH
# 164  SHS-GASTRO:GEN GASTROHEP-SGH
# 165  SHS-GASTRO:GEN GASTROHEP-SGH
# 166            SHS-IM:GEN MED-SGH
# 167       SHS-GASTRO:ADV ENDO-CGH
#
#                                                Answer:  Vader1 Score  \
# 0    Eliza Chen is starting out and therefore as ex...        0.8954
# 1    As a new senior resident to gastroenterology, ...        0.2732
# 2                                           No concern       -0.2960
# 3    Overall I would rate Eliza Chen highly as a SR...        0.8807
# 4    Eliza Chen has a quiet disposition and gives g...        0.6290
# ..                                                 ...           ...
# 163  did a week of bleeder call, good mgmt plans an...        0.3818
# 164  very competent, extremely professional, and a ...        0.7425
# 165  No issue. Making good progress compared to fir...        0.5423
# 166  Rachel is clinically competent and I can trust...        0.7184
# 167  Able to summarise key issues and suggest a rea...        0.5719
#
#      Textblob Score                                  Transformer Score  \
# 0          0.171429  TextClassificationResult(label='POSITIVE', sco...
# 1          0.136364  TextClassificationResult(label='POSITIVE', sco...
# 2          0.000000  TextClassificationResult(label='NEGATIVE', sco...
# 3          0.263750  TextClassificationResult(label='POSITIVE', sco...
# 4          0.330000  TextClassificationResult(label='POSITIVE', sco...
# ..              ...                                                ...
# 163        0.440625  TextClassificationResult(label='NEGATIVE', sco...
# 164        0.375000  TextClassificationResult(label='POSITIVE', sco...
# 165        0.475000  TextClassificationResult(label='POSITIVE', sco...
# 166        0.000000  TextClassificationResult(label='POSITIVE', sco...
# 167        0.233333  TextClassificationResult(label='POSITIVE', sco...
#
#                                              Doc_Embed  \
# 0    [[-0.6721534, -0.027664, 0.70268226, -0.476056...
# 1    [[-0.42423996, -0.6286227, 0.88219756, -0.6787...
# 2    [[-0.6876688, 0.02974713, 0.109754026, 0.12074...
# 3    [[-0.6283155, -0.20029192, 1.1669189, -0.10387...
# 4    [[-0.8619444, -0.18374743, 0.21259235, 0.16743...
# ..                                                 ...
# 163  [[0.1212126, -0.52477044, 1.1620986, -0.917062...
# 164  [[-0.2288021, -0.4193769, 0.4208119, 0.1031569...
# 165  [[-0.34792647, -1.0121427, 0.16201107, -1.0558...
# 166  [[-0.5686393, -0.43344223, 0.682797, 0.342227,...
# 167  [[-0.59468305, -0.25439933, 1.5317823, -0.1208...
#
#                                               Distance  \
# 0    [[-0.09625689, 0.11881207, 1.9541476e-05, 0.09...
# 1    [[-0.0859189, 0.17790526, -0.016277257, 0.0281...
# 2    [[0.6711223, 0.41983747, 0.5360163, 0.5921104,...
# 3    [[0.028535588, 0.28990865, 0.0832851, 0.186433...
# 4    [[-0.0062184343, 0.13000053, 0.01491292, 0.150...
# ..                                                 ...
# 163  [[-0.061233785, 0.28290597, 0.0270812, -0.0234...
# 164  [[0.2495091, 0.22908753, 0.33462763, 0.5758852...
# 165  [[0.42752415, 0.48969555, 0.44772327, 0.458115...
# 166  [[-0.14905263, 0.09871096, -0.12953652, 0.0126...
# 167  [[0.09124422, 0.28660053, 0.08596024, 0.294353...
#
#                                               Keywords  Answer
# 0    [outpatient, professionalism, holistic, teacha...       5
# 1    [pharmacists, medicine, inpatients, inpatient,...       7
# 2       [quiet, independently, minimal, passive, lack]       5
# 3     [medical, doctors, healthcare, nurses, medicine]       7
# 4      [caring, calm, diligent, polite, introspective]       5
# ..                                                 ...     ...
# 163  [outpatient, medicine, colonoscopes, 2022, col...       8
# 164  [professionalism, treasured, reliable, efficie...       7
# 165    [maturity, completed, matures, mature, matured]       8
# 166  [doctors, medicine, inpatient, inpatients, nur...       7
# 167  [inpatients, medical, inpatient, healthcare, m...       7
#
# [168 rows x 12 columns]

# %%
# Create a boxplot
score_comments.boxplot(column='Vader1 Score', by='Answer')

# Set the axis labels and title
plt.xlabel('Ordinal Categorical Variable')
plt.ylabel('Continuous Variable')
plt.title('Boxplot of Continuous Variable by Ordinal Categorical Variable')

# Show the plot
plt.show()

# %%
# Create a scatter plot using seaborn
sns.scatterplot(y='Vader1 Score', x='Answer', data=score_comments)

# Add a best fit line to the scatter plot
sns.regplot(y='Vader1 Score', x='Answer', data=score_comments)

# Display the plot
plt.show()

# %%
import pandas as pd
comments=pd.read_excel('evaluations_overall_comments.xlsx')
comments
# Out:
#          Target:                      Evaluator:       Rotation Dates:  \
# 0     Eliza Chen      Dr. Ong, Andrew Ming Liang    7/1/2022-7/31/2022
# 1     Eliza Chen         Dr. Chan, Webber Pak Wo    7/1/2022-7/31/2022
# 2     Eliza Chen              Dr. Lim, Chee Hooi    7/1/2022-7/31/2022
# 3     Eliza Chen         Dr. Chang, Jason Pik Eu    8/1/2022-8/31/2022
# 4     Eliza Chen              Dr. Tan, Chee Kiat    8/1/2022-8/31/2022
# ..           ...                             ...                   ...
# 163  Rachel Yeap     Dr. Tan, Malcolm Teck Kiang    7/1/2022-7/31/2022
# 164  Rachel Yeap  Dr. Khor, Christopher Jen Lock    8/1/2022-8/31/2022
# 165  Rachel Yeap               Dr. Liou, Wei Lun    8/1/2022-8/31/2022
# 166  Rachel Yeap             Dr. Loo, Khang Ning    9/1/2022-10/2/2022
# 167  Rachel Yeap        Dr. Kwek, Andrew Boon Eu  10/3/2022-10/31/2022
#
#                          Service:  \
# 0                             - -
# 1       SHS-GASTRO:BASIC ENDO-SGH
# 2       SHS-GASTRO:BASIC ENDO-SGH
# 3       SHS-GASTRO:BASIC ENDO-SGH
# 4       SHS-GASTRO:BASIC ENDO-SGH
# ..                            ...
# 163  SHS-GASTRO:GEN GASTROHEP-SGH
# 164  SHS-GASTRO:GEN GASTROHEP-SGH
# 165  SHS-GASTRO:GEN GASTROHEP-SGH
# 166            SHS-IM:GEN MED-SGH
# 167       SHS-GASTRO:ADV ENDO-CGH
#
#                                                Answer:
# 0    Eliza Chen is starting out and therefore as ex...
# 1    As a new senior resident to gastroenterology, ...
# 2                                           No concern
# 3    Overall I would rate Eliza Chen highly as a SR...
# 4    Eliza Chen has a quiet disposition and gives g...
# ..                                                 ...
# 163  did a week of bleeder call, good mgmt plans an...
# 164  very competent, extremely professional, and a ...
# 165  No issue. Making good progress compared to fir...
# 166  Rachel is clinically competent and I can trust...
# 167  Able to summarise key issues and suggest a rea...
#
# [168 rows x 5 columns]

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []
 
 
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# Tasks:
# emoji, emotion, hate, irony, offensive, sentiment
# stance/abortion, stance/atheism, stance/climate, stance/feminist, stance/hillary

task='sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

tokenizer = AutoTokenizer.from_pretrained(MODEL)

# download label mapping
labels=[]
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels = [row[1] for row in csvreader if len(row) > 1]

# PT
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
model.save_pretrained(MODEL)

comments['processed']=comments['Answer:'].apply(lambda x: preprocess(x))
comments['encoded']=comments['processed'].apply(lambda x:tokenizer(x,return_tensors='pt'))
comments['output']=comments['encoded'].apply(lambda x:model(**x))
comments['scores']=comments['output'].apply(lambda x:softmax(x[0][0].detach().numpy()))
print(comments)
# text = "Good night 😊"
# text = preprocess(text)
# encoded_input = tokenizer(text, return_tensors='pt')
# output = model(**encoded_input)
# scores = output[0][0].detach().numpy()
# scores = softmax(scores)

# # TF
# model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
# model.save_pretrained(MODEL)

# text = "Good night 😊"
# encoded_input = tokenizer(text, return_tensors='tf')
# output = model(encoded_input)
# scores = output[0][0].numpy()
# scores = softmax(scores)

ranking = np.argsort(scores)
ranking = ranking[::-1]
for i in range(scores.shape[0]):
    l = labels[ranking[i]]
    s = scores[ranking[i]]
    print(f"{i+1}) {l} {np.round(float(s), 4)}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22864\2671409525.py in <module>
#      25 MODEL = f"poot/sentiment-model"
#      26
# ---> 27 tokenizer = AutoTokenizer.from_pretrained(MODEL,local_files_only=True)
#      28
#      29 # download label mapping
#
# c:\Users\WongQiHuiYve\Anaconda3\lib\site-packages\transformers\models\auto\tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     674             tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#     675             if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 676                 return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     677             else:
#     678                 if tokenizer_class_py is not None:
#
# c:\Users\WongQiHuiYve\Anaconda3\lib\site-packages\transformers\tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1786
#    1787         if all(full_file_name is None for full_file_name in resolved_vocab_files.values()):
# -> 1788             raise EnvironmentError(
#    1789                 f"Can't load tokenizer for '{pretrained_model_name_or_path}'. If you were trying to load it from "
#    1790                 "'https://huggingface.co/models', make sure you don't have a local directory with the same name. "
#
# OSError: Can't load tokenizer for 'poot/sentiment-model'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'poot/sentiment-model' is the correct path to a directory containing all relevant files for a RobertaTokenizerFast tokenizer.

# %%
comments['neu']=comments['scores'].apply(lambda x: x[1])
comments[['Answer:','neu']].loc[comments['neu']>0.7].iloc[6]
# Out:
# Answer:    Knowledge aspect needs further improvement
# neu                                          0.700757
# Name: 89, dtype: object

# %%
comments['neg']=comments['scores'].apply(lambda x: x[0])
comments[['Answer:','neg']].loc[comments['neg']>0.3].values.tolist()
# Out:
# [['Xiuhuan cares for her patients and that\'s evident from how she greets them as people when doing the round (as opposed to patients). However she needs to apply herself more. Although she is gaining the skills and knowledge requisite of her level, she needs to remember that she is training to be a consultant and not a SR. She sometimes "hedges" her diagnosis and this approach will make her less effective in the long run.',
#   0.4184384047985077],
#  ['enthusiastic but sometimes may lost focus', 0.37071284651756287],
#  ['I think overall whilst Andre is not a malignant person, he requires supervision to complete his tasks. With regards to his leave practices, to give him the benefit of the doubt, he "might not have known" and he certainly has needs for his family, however the lack of consideration on the impact of his own learning, and the impact this has on others having to cover him for weekends and ward duties is of concern.',
#   0.47441616654396057],
#  ['I have not written much in this assessment. It is essentially the same with the previous one.',
#   0.32307708263397217]]

# %%
comments['pos']=comments['scores'].apply(lambda x: x[2])
comments[['Answer:','pos']].loc[comments['pos']<0.2].values.tolist()
# Out:
# [['No concern', 0.07848860323429108],
#  ['Eliza Chen has a quiet disposition and gives good thoughts to her management. However, because she is a bit too quiet, she does not project the impression that she have good control over her subordinates. There were knowledge gaps as we discuss cases - she is aware of them and has insight.',
#   0.19857768714427948],
#  ['Please see comments above', 0.04341280087828636],
#  ['No concern', 0.07848860323429108],
#  ['Had a short week with her, hence limited interactions.',
#   0.032620709389448166],
#  ['able to act independently in most of the clinical situation',
#   0.08608968555927277],
#  ['Keen to learn, follows through on tasks, technical competencies adequate for level of training, takes effort to reflect on learning points',
#   0.18451350927352905],
#  ['Xiuhuan cares for her patients and that\'s evident from how she greets them as people when doing the round (as opposed to patients). However she needs to apply herself more. Although she is gaining the skills and knowledge requisite of her level, she needs to remember that she is training to be a consultant and not a SR. She sometimes "hedges" her diagnosis and this approach will make her less effective in the long run.',
#   0.08456621319055557],
#  ['enthusiastic but sometimes may lost focus', 0.054053157567977905],
#  ['As per earlier comments', 0.04566922411322594],
#  ['He needs to be more proactive in learning . He is quite passive in learning and asking senior.',
#   0.10874912887811661],
#  ['I think overall whilst Andre is not a malignant person, he requires supervision to complete his tasks. With regards to his leave practices, to give him the benefit of the doubt, he "might not have known" and he certainly has needs for his family, however the lack of consideration on the impact of his own learning, and the impact this has on others having to cover him for weekends and ward duties is of concern.',
#   0.04067535325884819],
#  ["We had discussed previously about Andre's 5 periods of leave during this posting which curtailed learning opportunities for the Mon am IBD list, Mon PM nutrition clinic and the Wed am nutrition round. He was given feedback to limit his leave to 1x month and to report his intention to take leave in such a manner to the faculty in a posting. He has made effort to improve his medical knowledge to a reasonable level and makes an attempt to go through the case, however it feels like he needs more time to move from a reporter and interpetator of information to offer management in a manner that reflects a specialist in training",
#   0.13138918578624725],
#  ['I have not written much in this assessment. It is essentially the same with the previous one.',
#   0.04867766052484512],
#  ['keen to learn. No major issue. Need to be more careful and thorough in evaluating patients with decompensated cirrhosis.',
#   0.12460265308618546],
#  ['will need more guidance', 0.04434308037161827]]

# %%
comments[['Answer:','scores']]
# Out:
#                                                Answer:  \
# 0    Eliza Chen is starting out and therefore as ex...
# 1    As a new senior resident to gastroenterology, ...
# 2                                           No concern
# 3    Overall I would rate Eliza Chen highly as a SR...
# 4    Eliza Chen has a quiet disposition and gives g...
# ..                                                 ...
# 163  did a week of bleeder call, good mgmt plans an...
# 164  very competent, extremely professional, and a ...
# 165  No issue. Making good progress compared to fir...
# 166  Rachel is clinically competent and I can trust...
# 167  Able to summarise key issues and suggest a rea...
#
#                                      scores
# 0      [0.012829757, 0.21647434, 0.7706959]
# 1    [0.0025204902, 0.059670344, 0.9378091]
# 2       [0.17661668, 0.74489474, 0.0784886]
# 3       [0.010495567, 0.1125953, 0.8769091]
# 4       [0.18982491, 0.6115974, 0.19857769]
# ..                                      ...
# 163       [0.07528579, 0.526805, 0.3979092]
# 164    [0.002622035, 0.022788968, 0.974589]
# 165   [0.0041091316, 0.06917517, 0.9267157]
# 166   [0.010198248, 0.18377367, 0.80602807]
# 167    [0.014538733, 0.25270712, 0.7327542]
#
# [168 rows x 2 columns]

# %%
# year of training (Personal Details)
# compliance (Didactic Attendance)
# comment score (Evaluation)
# answer score (Evaluation)
# procedure (Procedure Log)

# %%
personal=pd.read_excel('personal_details.xlsx')
eval_scores=pd.read_excel('evaluations_overall_score.xlsx')

didactic=pd.read_excel('didactic_attendance.xlsx')
didactic
# Out:
#          MCR          Target:   Mmm/Yyyy Posting Institution  \
# 0    M60683J        Andre Tan 2022-07-01                 SGH
# 1    M64141I       Eliza Chen 2022-07-01                 SGH
# 2    M61612G     Gabrielle Ho 2022-07-01                 CGH
# 3    M63062J    Jiang Xiao Ye 2022-07-01                 CGH
# 4    M62077E    Kang Hyun Bin 2022-07-01                 CGH
# ..       ...              ...        ...                 ...
# 97   M62162F          Sam Lim 2022-12-01                 SGH
# 98   M19919H  Christopher Tan 2022-12-01                 SGH
# 99   M65113A      Tang Ye Bin 2022-12-01                 SGH
# 100  M61467A    Francisco Tan 2022-12-01                 SGH
# 101  M63484C      Rachel Yeap 2022-12-01                 CGH
#
#     Posting Department  Attended Teachings  Scheduled Teachings  % Compliance
# 0            SGHGasEnt                  14                   14      1.000000
# 1            SGHGasEnt                  12                   14      0.857143
# 2            CGHGasHep                   9                   12      0.750000
# 3            CGHGasHep                  12                   12      1.000000
# 4            CGHGasHep                   9                   12      0.750000
# ..                 ...                 ...                  ...           ...
# 97           SGHGasEnt                  13                   14      0.928571
# 98           SGHGasEnt                  12                   14      0.857143
# 99           SGHGasEnt                  13                   14      0.928571
# 100          SGHGasEnt                  12                   14      0.857143
# 101          CGHGasHep                  10                   12      0.833333
#
# [102 rows x 8 columns]

# %%
didactic[['Target:','% Compliance']]
print(personal[['MCR No','Year of Training']])
print(exam_score[['Target:','Answer']])
# Out:
#      MCR No Year of Training
# 0   M64141I              SR1
# 1   M63216A              SR1
# 2   M64837A              SR1
# 3   M63612H              SR1
# 4   M62162F              SR1
# 5   M61612G              SR2
# 6   M63062J              SR2
# 7   M61079A              SR2
# 8   M65113A              SR2
# 9   M61467A              SR2
# 10  M63484C              SR2
# 11  M60683J              SR3
# 12  M62077E              SR3
# 13  M61370G              SR3
# 14  M64015B              SR3
# 15  M62157E              SR3
# 16  M19919H              SR3
#          Target:  Answer
# 0     Eliza Chen       5
# 1     Eliza Chen       7
# 2     Eliza Chen       5
# 3     Eliza Chen       7
# 4     Eliza Chen       5
# ..           ...     ...
# 163  Rachel Yeap       8
# 164  Rachel Yeap       7
# 165  Rachel Yeap       8
# 166  Rachel Yeap       7
# 167  Rachel Yeap       7
#
# [168 rows x 2 columns]

# %%
didactic
# Out:
#          MCR          Target:   Mmm/Yyyy Posting Institution  \
# 0    M60683J        Andre Tan 2022-07-01                 SGH
# 1    M64141I       Eliza Chen 2022-07-01                 SGH
# 2    M61612G     Gabrielle Ho 2022-07-01                 CGH
# 3    M63062J    Jiang Xiao Ye 2022-07-01                 CGH
# 4    M62077E    Kang Hyun Bin 2022-07-01                 CGH
# ..       ...              ...        ...                 ...
# 97   M62162F          Sam Lim 2022-12-01                 SGH
# 98   M19919H  Christopher Tan 2022-12-01                 SGH
# 99   M65113A      Tang Ye Bin 2022-12-01                 SGH
# 100  M61467A    Francisco Tan 2022-12-01                 SGH
# 101  M63484C      Rachel Yeap 2022-12-01                 CGH
#
#     Posting Department  Attended Teachings  Scheduled Teachings  % Compliance
# 0            SGHGasEnt                  14                   14      1.000000
# 1            SGHGasEnt                  12                   14      0.857143
# 2            CGHGasHep                   9                   12      0.750000
# 3            CGHGasHep                  12                   12      1.000000
# 4            CGHGasHep                   9                   12      0.750000
# ..                 ...                 ...                  ...           ...
# 97           SGHGasEnt                  13                   14      0.928571
# 98           SGHGasEnt                  12                   14      0.857143
# 99           SGHGasEnt                  13                   14      0.928571
# 100          SGHGasEnt                  12                   14      0.857143
# 101          CGHGasHep                  10                   12      0.833333
#
# [102 rows x 8 columns]

# %%
exam_score_groupby=exam_score.groupby('Target:')['Answer'].mean()
exam_score_groupby=exam_score_groupby.to_frame()
didactic_groupby=didactic.groupby('Target:')['% Compliance'].mean()
didactic_groupby=didactic_groupby.to_frame()

# %%
comments

# %%
comments_groupby=comments.groupby('Target:')['pos'].mean()
comments_groupby=comments_groupby.to_frame()

# %%
cluster_df=comments_groupby.merge(exam_score_groupby,how='inner',on='Target:').merge(didactic_groupby,how='inner',on='Target:')

# %%
cluster_df
# Out:
#                        pos    Answer  % Compliance
# Target:
# Amanda Koh        0.702590  6.363636      0.795635
# Andre Tan         0.627803  6.250000      0.831349
# Christopher Tan   0.742413  8.750000      0.819444
# Eliza Chen        0.618651  6.200000      0.924603
# Francisco Tan     0.782295  7.250000      0.928571
# Gabrielle Ho      0.642040  7.000000      0.805556
# James Wang        0.657804  5.857143      0.888889
# Jiang Xiao Ye     0.738620  7.625000      0.851190
# Justin Bieber     0.711947  7.375000      0.865079
# Kang Hyun Bin     0.801843  7.571429      0.809829
# Li Xiuhuan        0.610494  7.153846      0.806777
# Pei Wei Ping      0.788716  8.000000      0.892857
# Qiu Tian Ning     0.732062  6.000000      0.861111
# Rachel Yeap       0.791888  7.500000      0.855159
# Rahul Rajaratnam  0.742675  7.888889      0.821581
# Sam Lim           0.744221  7.000000      0.904762
# Tang Ye Bin       0.613052  7.583333      0.952381

# %%
model_5 = KMeans(n_clusters = 5, random_state=0)
type(model_5)
model_5.fit(news_2var).inertia_

# %%
import seaborn as sns
sns.heatmap(cluster_df, cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22864\2327580896.py in <module>
#       1 import seaborn as sns
# ----> 2 sns.heatmap(cluster_df, cmap="YlGnBu")
#
# NameError: name 'cluster_df' is not defined
