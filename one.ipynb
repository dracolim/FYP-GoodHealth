# %%
# !pip install Faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/maarunipandithurai/Documents/maars202/school_6/flask-vuejs-template/env/bin/python3 -m pip install --upgrade pip' command.

# %%
from faker import Faker
fake = Faker()

fake.name()
# 'Lucy Cechtelar'

fake.address()
# '426 Jordy Lodge
#  Cartwrightshire, SC 88120-6700'

fake.text()
# 'Sint velit eveniet. Rerum atque repellat voluptatem quia rerum. Numquam excepturi
#  beatae sint laudantium consequatur. Magni occaecati itaque sint et sit tempore. Nesciunt
#  amet quidem. Iusto deleniti cum autem ad quia aperiam.
#  A consectetur quos aliquam. In iste aliquid et aut similique suscipit. Consequatur qui
#  quaerat iste minus hic expedita. Consequuntur error magni et laboriosam. Aut aspernatur
#  voluptatem sit aliquam. Dolores voluptatum est.
#  Aut molestias et maxime. Fugit autem facilis quos vero. Eius quibusdam possimus est.
#  Ea quaerat et quisquam. Deleniti sunt quam. Adipisci consequatur id in occaecati.
#  Et sint et. Ut ducimus quod nemo ab voluptatum.'
# Out:
# 'Man white fill player. Return threat culture choice become.\nThe language fine.'

# %%
for _ in range(10):
  print(fake.name())
# Out:
# Phillip Wilson
# Sandra Roberts
# Sophia Anderson
# Tony Hunt
# Marissa Ortega
# Timothy Potts
# Alisha Smith MD
# Gerald Cain
# Brenda Thomas
# Darryl Anderson

# %%
from random import random, randint
optionsDesignation = ["Senior Resident", "Junior Doctor"]
optionsDesignation[randint(0, len(optionsDesignation)-1)]
# Out:
# 'Senior Resident'

# %%
random()*len(optionsDesignation)
# Out:
# 0.39019641476541

# %%
for _ in range(5):
    name = fake.name()
    print("name: ", name)
    print("postalcode", fake.postcode())
    print("streetaddress", fake.street_address())
    print("street_name", fake.street_address())
    print("unit number", fake.building_number())
    print("building_number", fake.building_number())
    print("current_country: ", fake.current_country())
    print("contactno: ", fake.phone_number())
    print("date_time_between: ", fake.date_time_between())
    newname = ""
    for i in name:
        if i != " ":
            newname += i
    print("email: ", newname.lower() + "@gmail.com")
    print("------")
# Out:
# name:  Erica Hughes
# postalcode 62372
# streetaddress 0388 Donovan Station
# street_name 8200 Ward Loaf Suite 710
# unit number 2200
# building_number 05426
# current_country:  United States
# contactno:  018-518-4598
# date_time_between:  1993-11-25 16:31:14
# email:  ericahughes@gmail.com
# ------
# name:  Robin Davis
# postalcode 88875
# streetaddress 9455 Kevin Shoals Apt. 536
# street_name 989 Travis Estates Suite 697
# unit number 4297
# building_number 91718
# current_country:  United States
# contactno:  (067)250-0694
# date_time_between:  2022-06-30 20:59:34
# email:  robindavis@gmail.com
# ------
# name:  Walter Carrillo
# postalcode 78681
# streetaddress 1992 Eric Fields
# street_name 316 Wiley Harbors Suite 727
# unit number 145
# building_number 0056
# current_country:  United States
# contactno:  001-655-728-2876x3411
# date_time_between:  2017-06-23 15:19:18
# email:  waltercarrillo@gmail.com
# ------
# name:  Juan Kent
# postalcode 28537
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.8/249.8 KB 5.4 MB/s eta 0:00:000:00:01
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/maarunipandithurai/Documents/maars202/school_6/flask-vuejs-template/env/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
personal_details = pd.read_excel('./(BE Request)Database Template for Residency (1).xlsx',
                                 sheet_name = 'Personal Details')

# %%
personal_details
# Out:
#    Employee ID/ MOHH Employee No   MCR No           Staff Name  \
# 0                       MOM12390  M11367A         Daniel Tyler
# 1                       MOM05233  M16782H             Betty Li
# 2                       MOM07177  M65889A            Sally Pei
# 3                       MOM05609  M54354E     Rahul Rajaratnam
# 4                       MOM05690  M88791Z        Kang Hyun Bin
# 5                       MOM05579  M56829J  Ivanka Lee Xiao Wei
# 6                       MOM04393  M83162D           Cindee Tan
# 7                       MOM05601  M33571G       Koh Zheng Tang
# 8                       MOM06600  M35718D         Malcolm Tang
# 9                       MOM06313  M35589A  Koh Xiaojia Lynette
# 10                      MOM05705  M66630D    Toh Jiahao Thomas
# 11                      MOM05928  M45528I   Brendan Lee Potter
# 12                      MOM05459  M65659J           Chen Youyi
#
#         Designation             Programme Year of Training  Academic Year  \
# ...

# %%
personal_details.columns
# Out:
# Index(['Employee ID/ MOHH Employee No', 'MCR No', 'Staff Name', 'Designation',
#        'Programme', 'Year of Training', 'Academic Year', 'Department',
#        'Institution', 'Academic Clinical Programme', 'Employment Status',
#        'Nationality', 'Date of Birth', 'Gender', 'Registration Type',
#        'House/ Blk No', 'Street', 'Building Name', 'Unit No', 'Postal Code',
#        'Contact No (Work)', 'Contact No (Personal)', 'Email (Official)',
#        'Email (Personal)', 'BCLS Expiry Date', 'ACLS Expiry Date',
#        'COVID-19 Vaccination Status', 'Date of First Dose',
#        'Date of Second Dose', 'Vaccination Remarks'],
#       dtype='object')

# %%
    name = fake.name()
    print("name: ", name)
    print("postalcode", fake.postcode())
    print("streetaddress", fake.street_address())
    print("street_name", fake.street_address())
    print("unit number", fake.building_number())
    print("building_number", fake.building_number())
    print("current_country: ", fake.current_country())
    print("contactno: ", fake.phone_number())
    print("date_time_between: ", fake.date_time_between())
    newname = ""
    for i in name:
        if i != " ":
            newname += i
    print("email: ", newname.lower() + "@gmail.com")
# Out:
# name:  George Haynes
# postalcode 37331
# streetaddress 3794 Kim Locks
# street_name 563 Obrien Falls Suite 010
# unit number 8073
# building_number 6261
# current_country:  United States
# contactno:  (902)316-8770x781
# date_time_between:  2014-02-16 02:35:49
# email:  georgehaynes@gmail.com

# %%
data_no = 20

def add_more_personal_details(personal_details):
    data_no = 20
    for i in range(data_no):
        name = fake.name()
        newname = ""
        for i in name:
            if i != " ":
                newname += i
        email = newname.lower() + "@gmail.com"
        personal_details = personal_details.append(
        {'Employee ID/ MOHH Employee No': "MOM" + str(fake.pyint(1000, 10000)), 
            'MCR No': "MOM" + str(fake.pyint(1000, 10000)), 
            'Staff Name': name, 
            'Designation': "Senior Resident",
            #  MAKE random
        'Programme': "Gastroenterology", 
        'Year of Training': "SR2", 
        'Academic Year': "2022", 
        'Department': "Residency",
        'Institution': "MOHH", 
        'Academic Clinical Programme': "Medicine", 
        'Employment Status': "Active",
        'Nationality': "Singaporean", 
        'Date of Birth': fake.date_time_between(), 
        #  MAKE random
        'Gender': "Female", 
        #  MAKE random
        'Registration Type': "Full",
        'House/ Blk No': fake.building_number(), 
        'Street': fake.street_address(), 
        'Building Name': fake.building_number(), 
        'Unit No': fake.building_number(), 
        'Postal Code': fake.postcode(),
        'Contact No (Work)': fake.phone_number(), 
        'Contact No (Personal)': fake.phone_number(), 
        'Email (Official)': email,
        'Email (Personal)': email, 
        'BCLS Expiry Date': fake.date_time_between(), 
        'ACLS Expiry Date': fake.date_time_between(),
        #  MAKE random
        'COVID-19 Vaccination Status': "Yes", 
        'Date of First Dose': fake.date_time_between(),
        'Date of Second Dose': fake.date_time_between(), 
        'Vaccination Remarks': ""}, ignore_index=True)
    return personal_details

personal_details = add_more_personal_details(personal_details)
# Out:
# /var/folders/5w/_dklzgjj1nvgxqdrqjw_94v80000gn/T/ipykernel_42429/577288389.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   personal_details = personal_details.append(
# /var/folders/5w/_dklzgjj1nvgxqdrqjw_94v80000gn/T/ipykernel_42429/577288389.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   personal_details = personal_details.append(
# /var/folders/5w/_dklzgjj1nvgxqdrqjw_94v80000gn/T/ipykernel_42429/577288389.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   personal_details = personal_details.append(
# ...

# %%
personal_details
# Out:
#    Employee ID/ MOHH Employee No   MCR No             Staff Name  \
# 0                       MOM12390  M11367A           Daniel Tyler
# 1                       MOM05233  M16782H               Betty Li
# 2                       MOM07177  M65889A              Sally Pei
# 3                       MOM05609  M54354E       Rahul Rajaratnam
# 4                       MOM05690  M88791Z          Kang Hyun Bin
# 5                       MOM05579  M56829J    Ivanka Lee Xiao Wei
# 6                       MOM04393  M83162D             Cindee Tan
# 7                       MOM05601  M33571G         Koh Zheng Tang
# 8                       MOM06600  M35718D           Malcolm Tang
# 9                       MOM06313  M35589A    Koh Xiaojia Lynette
# 10                      MOM05705  M66630D      Toh Jiahao Thomas
# 11                      MOM05928  M45528I     Brendan Lee Potter
# 12                      MOM05459  M65659J             Chen Youyi
# ...

# %%
personal_details.to_excel("newdata_personaldetails.xlsx")

# %%
fake.date_time_between().strftime("%H:%M:%S")
# Out:
# '19:06:48'
